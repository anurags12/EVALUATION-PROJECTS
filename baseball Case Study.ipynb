# %% [markdown]
# # Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fieldin8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a-- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#  result.
# g error.

# %% [markdown]
# # Dataset Link-
# •	https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/Baseball/baseball.cs

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading dataset
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Columns Name
df.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
# renaming Columns 
df.rename(columns={'W':'Wins',
                  'R':'Runs Scored',
                  'AB':'At Bat',
                  'H':'Hit',
                  '2B':'Two-Bagger',
                  '3B':'Three-Bagger',
                  'HR':'Home Runs',
                  'BB':'Base on Balls',
                  'SO':'Strike Out',
                  'SB':'Stolen Base',
                  'RA':'Run Average',
                  'ER':'Earned Run',
                  'ERA':'Earned Run Average',
                  'CG':'Complete Game',
                  'SHO':'ShutOut',
                  'SV':'Save',
                  'E':'Errors'},inplace=True)

# %%
df.columns
# Out:
# Index(['Wins', 'Runs Scored', 'At Bat', 'Hit', 'Two-Bagger', 'Three-Bagger',
#        'Home Runs', 'Base on Balls', 'Strike Out', 'Stolen Base',
#        'Run Average', 'Earned Run', 'Earned Run Average', 'Complete Game',
#        'ShutOut', 'Save', 'Errors'],
#       dtype='object')

# %%
# Rowns and columns in dataset
print('DataSet has "{}" rows and "{}" columns.'.format(df.shape[0],df.shape[1]))
# Out:
# DataSet has "30" rows and "17" columns.

# %% [markdown]
# In 17 columns ,Wins is our target variable and rest is independent variable

# %%
# Checking Datatype
df.dtypes
# Out:
# Wins                    int64
# Runs Scored             int64
# At Bat                  int64
# Hit                     int64
# Two-Bagger              int64
# Three-Bagger            int64
# Home Runs               int64
# Base on Balls           int64
# Strike Out              int64
# Stolen Base             int64
# Run Average             int64
# Earned Run              int64
# Earned Run Average    float64
# Complete Game           int64
# ShutOut                 int64
# Save                    int64
# Errors                  int64
# dtype: object

# %% [markdown]
# In this dataset two types of data is present.
# 1) int
# 2) float

# %%
# Checking Data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs Scored         30 non-null     int64
#  2   At Bat              30 non-null     int64
#  3   Hit                 30 non-null     int64
#  4   Two-Bagger          30 non-null     int64
#  5   Three-Bagger        30 non-null     int64
#  6   Home Runs           30 non-null     int64
#  7   Base on Balls       30 non-null     int64
#  8   Strike Out          30 non-null     int64
#  9   Stolen Base         30 non-null     int64
#  10  Run Average         30 non-null     int64
#  11  Earned Run          30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Game       30 non-null     int64
#  14  ShutOut             30 non-null     int64
#  15  Save                30 non-null     int64
# ...

# %%
# Checking Null Values
df.isnull().sum()
# Out:
# Wins                  0
# Runs Scored           0
# At Bat                0
# Hit                   0
# Two-Bagger            0
# Three-Bagger          0
# Home Runs             0
# Base on Balls         0
# Strike Out            0
# Stolen Base           0
# Run Average           0
# Earned Run            0
# Earned Run Average    0
# Complete Game         0
# ShutOut               0
# Save                  0
# Errors                0
# dtype: int64

# %% [markdown]
# No null value is present in the dataset.

# %%
# Head
df.head(15)
# Out:
#     Wins  Runs Scored  At Bat   Hit  Two-Bagger  Three-Bagger  Home Runs  \
# 0     95          724    5575  1497         300            42        139
# 1     83          696    5467  1349         277            44        156
# 2     81          669    5439  1395         303            29        141
# 3     76          622    5533  1381         260            27        136
# 4     74          689    5605  1515         289            49        151
# 5     93          891    5509  1480         308            17        232
# 6     87          764    5567  1397         272            19        212
# 7     81          713    5485  1370         246            20        217
# 8     80          644    5485  1383         278            32        167
# 9     78          748    5640  1495         294            33        161
# 10    88          751    5511  1419         279            32        172
# 11    86          729    5459  1363         278            26        230
# ...

# %%
# tail
df.tail(15)
# Out:
#     Wins  Runs Scored  At Bat   Hit  Two-Bagger  Three-Bagger  Home Runs  \
# 15   100          647    5484  1386         288            39        137
# 16    98          697    5631  1462         292            27        140
# 17    97          689    5491  1341         272            30        171
# 18    68          655    5480  1378         274            34        145
# 19    64          640    5571  1382         257            27        167
# 20    90          683    5527  1351         295            17        177
# 21    83          703    5428  1363         265            13        177
# 22    71          613    5463  1420         236            40        120
# 23    67          573    5420  1361         251            18        100
# 24    63          626    5529  1374         272            37        130
# 25    92          667    5385  1346         263            26        187
# 26    84          696    5565  1486         288            39        136
# ...

# %%
# Count of Unique values
for d in df.columns:
    print('"{}" Unique values are present in {}.'.format(df[d].nunique(),d))
    print('\n')
# Out:
# "24" Unique values are present in Wins.
#
#
# "28" Unique values are present in Runs Scored.
#
#
# "29" Unique values are present in At Bat.
#
#
# "29" Unique values are present in Hit.
#
#
# "22" Unique values are present in Two-Bagger.
#
#
# "23" Unique values are present in Three-Bagger.
#
#
# "27" Unique values are present in Home Runs.
#
#
# "29" Unique values are present in Base on Balls.
#
#
# "29" Unique values are present in Strike Out.
#
#
# "27" Unique values are present in Stolen Base.
#
#
# "30" Unique values are present in Run Average.
#
#
# "30" Unique values are present in Earned Run.
#
#
# "30" Unique values are present in Earned Run Average.
#
#
# "9" Unique values are present in Complete Game.
#
#
# "12" Unique values are present in ShutOut.
#
#
# "20" Unique values are present in Save.
#
#
# "21" Unique values are present in Errors.

# %%
# Unique Values
for d in df.columns:
    print(d)
    print(df[d].unique())
    print('\n')
# Out:
# Wins
# [ 95  83  81  76  74  93  87  80  78  88  86  85  68 100  98  97  64  90
#   71  67  63  92  84  79]
#
#
# Runs Scored
# [724 696 669 622 689 891 764 713 644 748 751 729 661 656 694 647 697 655
#  640 683 703 613 573 626 667 720 650 737]
#
#
# At Bat
# [5575 5467 5439 5533 5605 5509 5567 5485 5640 5511 5459 5417 5544 5600
#  5484 5631 5491 5480 5571 5527 5428 5463 5420 5529 5385 5565 5649 5457
#  5572]
#
#
# Hit
# [1497 1349 1395 1381 1515 1480 1397 1370 1383 1495 1419 1363 1331 1379
#  1405 1386 1462 1341 1378 1382 1351 1420 1361 1374 1346 1486 1494 1324
#  1479]
#
#
# Two-Bagger
# [300 277 303 260 289 308 272 246 278 294 279 243 262 288 292 274 257 295
#  265 236 251 263]
#
#
# Three-Bagger
# [42 44 29 27 49 17 19 20 32 33 26 21 22 46 39 30 34 13 40 18 37 48 36]
#
#
# Home Runs
# [139 156 141 136 151 232 212 217 167 161 172 230 176 198 146 137 140 171
#  145 177 120 100 130 187 154 148 186]
#
#
# Base on Balls
# ...

# %%
# Checking value counts
for d in df.columns:
    print(d)
    print(df[d].value_counts())
    print('\n')
# Out:
# Wins
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64
#
#
# Runs Scored
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: Runs Scored, dtype: int64
#
#
# At Bat
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# ...

# %% [markdown]
# # Statistical Summary

# %%
# Description of Data
df.describe().T
# Out:
#                     count         mean         std      min        25%  \
# Wins                 30.0    80.966667   10.453455    63.00    74.0000
# Runs Scored          30.0   688.233333   58.761754   573.00   651.2500
# At Bat               30.0  5516.266667   70.467372  5385.00  5464.0000
# Hit                  30.0  1403.533333   57.140923  1324.00  1363.0000
# Two-Bagger           30.0   274.733333   18.095405   236.00   262.2500
# Three-Bagger         30.0    31.300000   10.452355    13.00    23.0000
# Home Runs            30.0   163.633333   31.823309   100.00   140.2500
# Base on Balls        30.0   469.100000   57.053725   375.00   428.2500
# Strike Out           30.0  1248.200000  103.759470   973.00  1157.5000
# Stolen Base          30.0    83.500000   22.815225    44.00    69.0000
# Run Average          30.0   688.233333   72.108005   525.00   636.2500
# Earned Run           30.0   635.833333   70.140786   478.00   587.2500
# ...

# %% [markdown]
# 1) mean is greater than median in Hit column. which means data is right skewed.
# 2) Outliers are present in Errors column because there is abnormal difference between 75th percentile and maximum data.

# %% [markdown]
# # Graphical Analysis

# %%
# Distribution of data in Runs Scored
sns.distplot(df['Runs Scored'])
plt.title('Data distribution in Runs Scored')
plt.show()

# %% [markdown]
# Normal distribution in Runs scored

# %%
# Data distribution in At bat
sns.distplot(df['At Bat'])
plt.title('Data distribution in At bat')
plt.show()

# %% [markdown]
# Normal Distribution in At BAt

# %%
# Data distribution in Hit
sns.distplot(df['Hit'])
plt.title('Data distribution in Hit')
plt.show()

# %% [markdown]
# graph is Normal distribution data in Hit.

# %%
# Data distribution in Two-bagger
sns.distplot(df['Two-Bagger'])
plt.title('Datadistribution in Two-Bagger')
plt.show()

# %% [markdown]
#  Normal distributed data in Two-Baggers

# %%
# Data distribution in Three-Bagger
sns.distplot(df['Three-Bagger'])
plt.title('Data distribution in Three-Bagger')
plt.show()

# %% [markdown]
# Normal Distributed data in Three-Baggers.

# %%
# Data distribution in Home Run
sns.distplot(df['Home Runs'])
plt.title('Data distribution in Home runs')
plt.show()

# %% [markdown]
# Normal Distributed data in Home Runs

# %%
# Data distribution in base on balls
sns.distplot(df['Base on Balls'])
plt.title('Data distribution in Base on balls')
plt.show()

# %% [markdown]
# graph is looking normally distributed in Base on Balls

# %%
# Data distribution Strike out
sns.distplot(df['Strike Out'])
plt.title('Data distribution in Strike Out')
plt.show()

# %% [markdown]
# Graph is looking normally distributed in strike out

# %%
# data distribution in Stolen Base
sns.distplot(df['Stolen Base'])
plt.title('Data distribution in stolen Base')
plt.show()

# %% [markdown]
# Data is looking normally distributed in stolen base

# %%
# Data distribution in Run Average
sns.distplot(df['Run Average'])
plt.title('Data distribution in Run Average')
plt.show()

# %% [markdown]
# Data is looking normally distributed in Run Average

# %%
# Data distribution in Earned Run
sns.distplot(df['Earned Run'])
plt.title('Data distribution in Earned Run')
plt.show()

# %% [markdown]
# Data is looking normally distributed in Earned run

# %%
# Data distribution in Earned Run Average
sns.distplot(df['Earned Run Average'])
plt.title('Data distribution in Earned Run Average')
plt.show()

# %% [markdown]
# Data is looking normally distributed in Earned Run Average

# %%
# Data distribution in Complete Game
sns.distplot(df['Complete Game'])
plt.title('Data distribution in Complete Game')
plt.show()

# %% [markdown]
# data is looking right skewed.

# %%
# Data distribution in ShutOut
sns.distplot(df['ShutOut'])
plt.title('Data Distribution in ShutOut')
plt.show()

# %% [markdown]
# data is looking normally distributed in Shut out.

# %%
# Data distribution in Save
sns.distplot(df['Save'])
plt.title('Data distribution in Save')
plt.show()

# %% [markdown]
# Normal data Distribution in Save

# %%
# Data distribution in Errors
sns.distplot(df['Errors'])
plt.title('Data distribution in Errors')
plt.show()

# %% [markdown]
# right skewed data in errors

# %% [markdown]
# Bivariae analysis

# %%
# Relation between Runs scored and wins
sns.scatterplot(x='Wins',y='Runs Scored',data=df)
plt.title('Relation between Runs Scored and Wins')
plt.show()

# %% [markdown]
# not any strong relation between wins and runs scsored

# %%
# Relation of At Bat with Wins
sns.scatterplot(x='Wins',y='At Bat',data=df)
plt.title('Relation of At Bat with Wins')
plt.show()

# %% [markdown]
# No relation between wins and At Bat

# %%
# Relation of Hit with Wins
sns.scatterplot(x='Wins',y='Hit',data=df)
plt.title('Realtion of Hit with Wins')
plt.show()

# %% [markdown]
# No relation between wins and Hit

# %%
# realtion of Two Bagger with Wins
sns.scatterplot(x='Wins',y='Two-Bagger',data=df)
plt.title('relation of Two-Bagger with Wins')
plt.show()

# %% [markdown]
# little positive relation between two bagger and woins

# %%
# Checking Relation of Three_bagger with WIns
sns.scatterplot(x='Wins',y='Three-Bagger',data=df)
plt.title('Relation of Three-Bagger with Wins')
plt.show()

# %% [markdown]
# no relation between wins and three bagger.

# %%
# Checking Relation of Home runs with Wins
sns.scatterplot(x='Wins',y='Home Runs',data=df)
plt.title('Relation of Home Runs with Wins')
plt.show()

# %% [markdown]
# positive relation between home runs and wins

# %%
# Checking realtion of Base on Balls with Wins
sns.scatterplot(x='Wins',y='Base on Balls',data=df)
plt.title('Relation with Base on Balls with Wins')
plt.show()

# %% [markdown]
# positive relation between base on balls and wins

# %%
# Checking Relation of Strike Out with Wins
sns.scatterplot(x='Wins',y='Strike Out',data=df)
plt.title('Relation with Strike out with Wins')
plt.show()

# %% [markdown]
# No relation between wins and strike out.

# %%
# Checking Relation Between Stolen Base with Wins
sns.scatterplot(x='Wins',y='Stolen Base',data=df)
plt.title('Relation of Stolen Base with Wins')
plt.show()

# %% [markdown]
# No relation between wins and Stolen Base.

# %%
#Checking Realtion with Run Average with Wins
sns.scatterplot(x='Wins',y='Run Average',data=df)
plt.title('Relation Between Run Average and Wins')
plt.show()

# %% [markdown]
# Negative relation between Run average and wins

# %%
# Checking relation of Earned run with Wins
sns.scatterplot(x='Wins',y='Earned Run',data=df)
plt.title('Relation of Earned Run with Wins')
plt.show()

# %% [markdown]
# Negative relation between Earned runs and wins

# %%
# Checking Relation of Earned Run Average with Wins
sns.scatterplot(x='Wins',y='Earned Run Average',data=df)
plt.title('Relation of Earned Run Average with Wins')
plt.show()

# %% [markdown]
# Negative relation between wins and Earned run average.

# %%
# Checking relation of Complete game with Wins
sns.scatterplot(x='Wins',y='Complete Game',data=df)
plt.title('Relation og Complete game with WIns')
plt.show()

# %% [markdown]
# No relation between wins and complete game

# %%
# Checking relation of ShutOut with Wins
sns.scatterplot(x='Wins',y='ShutOut',data=df)
plt.title('Relation of ShutOut with Wins')
plt.show()

# %% [markdown]
# weak positive relation between wins and shutout.

# %%
# Checking relation of Save with Wins
sns.scatterplot(x='Wins',y='Save',data=df)
plt.title('realtion of Save with Wins')
plt.show()

# %% [markdown]
# positive relation between wins and save

# %%
# checking relation of Errors with Wins
sns.scatterplot(x='Wins',y='Errors',data=df)
plt.title('Relation of Errors with Wins')
plt.show()

# %% [markdown]
# no relation between wins and errors.

# %% [markdown]
# Multi Variate Analysis

# %%
#PairPlot
sns.pairplot(df)
plt.show()

# %% [markdown]
# here we can see distribution of data in each column and relation between columns.

# %% [markdown]
# # Outliers and Skewness

# %%
# plotting boxplot to check outliers
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(15,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# Outlietrs are present in errors.

# %%
# Importing Zscore
from scipy.stats import zscore

# %%
# Checking Zscore
z=np.abs(zscore(df.iloc[:,1:]))
z
# Out:
#     Runs Scored    At Bat       Hit  Two-Bagger  Three-Bagger  Home Runs  \
# 0      0.619078  0.847731  1.663685    1.420173      1.041193   0.787299
# 1      0.134432  0.711094  0.970681    0.127403      1.235809   0.243967
# 2      0.332906  1.115233  0.151891    1.588795      0.223808   0.723377
# 3      1.146419  0.241522  0.401088    0.828122      0.418423   0.883181
# 4      0.013270  1.280738  1.984081    0.801892      1.722347   0.403770
# 5      3.509647  0.104884  1.361089    1.869832      1.391501   2.185047
# 6      1.311430  0.732263  0.116292    0.153633      1.196885   1.545833
# 7      0.428681  0.451289  0.596886    1.615025      1.099578   1.705636
# 8      0.765626  0.451289  0.365489    0.183611      0.068115   0.107601
# 9      1.034489  1.785913  1.628086    1.082929      0.165423   0.084163
# 10     1.086415  0.076017  0.275303    0.239818      0.068115   0.267405
# 11     0.705622  0.826562  0.721484    0.183611      0.515731   2.121125
# ...

# %%
# Threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
z.iloc[5][0]
# Out:
# 3.5096470447193067

# %%
# Removing outliers
dfn=df[np.abs(z<3).all(axis=1)]

# %%
print('"{}" row removed due to presence of outliers'.format(df.shape[0]-dfn.shape[0]) )
# Out:
# "1" row removed due to presence of outliers

# %% [markdown]
# Skewness

# %%
dfn.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hit                   0.783772
# Two-Bagger           -0.335304
# Three-Bagger          0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Out           -0.233815
# Stolen Base           0.494966
# Run Average           0.018155
# Earned Run            0.018461
# Earned Run Average    0.016693
# Complete Game         0.854980
# ShutOut               0.526943
# Save                  0.627480
# Errors                0.840271
# dtype: float64

# %% [markdown]
# Skewness is present in Hit, Complete game, shutout, save, errors.

# %%
# removing skewness
dfn['Hit']=np.cbrt(dfn['Hit'])
dfn['Complete Game']=np.sqrt(dfn['Complete Game'])
dfn['ShutOut']=np.sqrt(dfn['ShutOut'])
dfn['Save']=np.sqrt(dfn['ShutOut'])
dfn['Errors']=np.cbrt(dfn['Errors'])

# %%
dfn.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hit                   0.753696
# Two-Bagger           -0.335304
# Three-Bagger          0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Out           -0.233815
# Stolen Base           0.494966
# Run Average           0.018155
# Earned Run            0.018461
# Earned Run Average    0.016693
# Complete Game        -0.260678
# ShutOut              -0.085802
# Save                 -0.405019
# Errors                0.671748
# dtype: float64

# %%
dfn['Errors']=np.sqrt(dfn['Errors'])

# %%
dfn.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hit                   0.753696
# Two-Bagger           -0.335304
# Three-Bagger          0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Out           -0.233815
# Stolen Base           0.494966
# Run Average           0.018155
# Earned Run            0.018461
# Earned Run Average    0.016693
# Complete Game        -0.260678
# ShutOut              -0.085802
# Save                 -0.405019
# Errors                0.627851
# dtype: float64

# %% [markdown]
# # Correlation

# %%
# Using Heatmap to visualize correlation
plt.figure(figsize=(15,10))
sns.heatmap(dfn.corr(),annot=True)
plt.show()

# %% [markdown]
# 1) Run average, earned run and earned run average has high negative correlation with wins.
# 2) Complete game has least negative correlation with wins
# 3) Shutout and save has highest positive correlation with wins

# %% [markdown]
# Splitting Input Output variable

# %%
x=dfn.drop('Wins',axis=1)
y=dfn['Wins']

# %% [markdown]
# # Scaling Data

# %%
# Importing Standard Scaler
from sklearn.preprocessing import StandardScaler

# %%
# Scaling input data
x1=pd.DataFrame(StandardScaler().fit_transform(x),columns=x.columns)
x1
# Out:
#     Runs Scored    At Bat       Hit  Two-Bagger  Three-Bagger  Home Runs  \
# 0      0.959398  0.830084  1.728647    1.556538      1.010845  -0.765863
# 1      0.331147 -0.702831 -0.946162    0.201171      1.208917  -0.181389
# 2     -0.274666 -1.100253 -0.094708    1.733325     -0.276617  -0.697101
# 3     -1.329231  0.233951 -0.351839   -0.800621     -0.474688  -0.869006
# 4      0.174084  1.255894  2.041742    0.908319      1.704094  -0.353293
# 5      1.856900  0.716535 -0.058116   -0.093474     -1.266972   1.743939
# 6      0.712585 -0.447345 -0.555092   -1.625627     -1.167936   1.915843
# 7     -0.835605 -0.447345 -0.315000    0.260100      0.020490   0.196801
# 8      1.497899  1.752672  1.693704    1.202964      0.119526  -0.009484
# 9      1.565212 -0.078310  0.342114    0.319029      0.020490   0.368705
# 10     1.071586 -0.816380 -0.685001    0.260100     -0.573723   2.362794
# 11    -0.454167 -1.412514 -1.284608   -1.802414     -1.068901   0.506228
# ...

# %% [markdown]
# # Multicollinearity

# %%
# importing vif
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Creatin function
def calc_vif(data):
    VIF=pd.DataFrame()
    VIF['Columns']=data.columns
    VIF['vif value']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return VIF

# %%
# Checking Vif values
calc_vif(x1)
# Out:
#                Columns   vif value
# 0          Runs Scored    7.086011
# 1               At Bat   12.494283
# 2                  Hit    8.644783
# 3           Two-Bagger    3.635993
# 4         Three-Bagger    3.690742
# 5            Home Runs    8.470675
# 6        Base on Balls    4.126955
# 7           Strike Out    3.169178
# 8          Stolen Base    1.847075
# 9          Run Average  175.988522
# 10          Earned Run  929.118667
# 11  Earned Run Average  889.147545
# 12       Complete Game    2.300178
# 13             ShutOut  440.304264
# 14                Save  407.816467
# 15              Errors    2.041535

# %% [markdown]
# Multicollinearity is present in the data, hence going to drop column with high vif value and have less correlation with Wins(target variable).

# %%
# Dropping columns with highest VIF Value
x1.drop('Earned Run',axis=1,inplace=True)

# %%
calc_vif(x1)
# Out:
#                Columns   vif value
# 0          Runs Scored    6.100909
# 1               At Bat    7.915416
# 2                  Hit    8.636800
# 3           Two-Bagger    3.625240
# 4         Three-Bagger    3.632261
# 5            Home Runs    7.558161
# 6        Base on Balls    4.006107
# 7           Strike Out    3.161789
# 8          Stolen Base    1.845981
# 9          Run Average  166.936391
# 10  Earned Run Average  163.531298
# 11       Complete Game    2.300178
# 12             ShutOut  435.166267
# 13                Save  403.316963
# 14              Errors    2.039580

# %%
x1.drop('Save',axis=1,inplace=True)

# %%
calc_vif(x1)
# Out:
#                Columns   vif value
# 0          Runs Scored    6.026813
# 1               At Bat    7.308606
# 2                  Hit    8.508562
# 3           Two-Bagger    3.166840
# 4         Three-Bagger    3.106894
# 5            Home Runs    7.353100
# 6        Base on Balls    3.256983
# 7           Strike Out    2.735256
# 8          Stolen Base    1.658613
# 9          Run Average  136.631038
# 10  Earned Run Average  139.475087
# 11       Complete Game    2.166395
# 12             ShutOut    2.864471
# 13              Errors    2.022617

# %%
x1.drop('Run Average',axis=1,inplace=True)

# %%
calc_vif(x1)
# Out:
#                Columns  vif value
# 0          Runs Scored   5.982292
# 1               At Bat   4.364968
# 2                  Hit   6.882595
# 3           Two-Bagger   3.161347
# 4         Three-Bagger   3.028938
# 5            Home Runs   6.019830
# 6        Base on Balls   3.029107
# 7           Strike Out   2.217288
# 8          Stolen Base   1.640992
# 9   Earned Run Average   3.871712
# 10       Complete Game   2.165574
# 11             ShutOut   2.796750
# 12              Errors   1.994666

# %% [markdown]
# Removed Multicollinearity from dataset.

# %% [markdown]
# # Random State

# %%
# Importing Regression task Libraries
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score

# %%
# Creating function to find best random state
def best_RS(x,y):
    rs=0
    r2=0
    for i in range(1,150):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
        lr=LinearRegression()
        lr.fit(x_train,y_train)
        r2_s=r2_score(y_test,lr.predict(x_test))
        if r2_s>r2:
            r2=r2_s
            rs=i
    print('Best R2 {} at {}'.format(round(r2*100,2),rs))

# %%
best_RS(x1,y)
# Out:
# Best R2 85.1 at 50

# %%
# Splitting Training Testing data
xtrain,xtest,ytrain,ytest=train_test_split(x1,y,test_size=0.30,random_state=50)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (20, 13)
# (9, 13)
# (20,)
# (9,)

# %% [markdown]
# # Model

# %%
# Creating Model Variables
lr=LinearRegression()
rd=Ridge()
la=Lasso()
svr=SVR()
dtr=DecisionTreeRegressor()
knr=KNeighborsRegressor()
gbr=GradientBoostingRegressor()
rfr=RandomForestRegressor()
etr=ExtraTreesRegressor()
abr=AdaBoostRegressor()

# %%
# Creating list
models=[lr,rd,la,svr,dtr,knr,gbr,rfr,etr,abr]

# %%
# IteratingModels
for model in models:
    model.fit(xtrain,ytrain)
    r2_scr=r2_score(ytest,model.predict(xtest))
    mse=mean_squared_error(ytest,model.predict(xtest))
    mae=mean_absolute_error(ytest,model.predict(xtest))
    print('Model Name :-',model)
    print('Training Score:-',model.score(xtrain,ytrain))
    print('r2_Score',round(r2_scr*100,2))
    print('MSE',mse)
    print('MAE',mae)
    print('RMSE',np.sqrt(mean_squared_error(ytest,model.predict(xtest))))
    print('*'*100)
    print('Cross Val Score of :-',model)
    score_m=cross_val_score(model,x1,y)
    print(score_m)
    print(score_m.mean())
    print('Difference between r2_score and CV mean score of "{}" is :-'.format(model),r2_scr*100-score_m.mean()*100)
    print('\n')
# Out:
# Model Name :- LinearRegression()
# Training Score:- 0.822751023043963
# r2_Score 85.1
# MSE 21.380591994812804
# MAE 3.684806585876621
# RMSE 4.62391522357545
# ****************************************************************************************************
# Cross Val Score of :- LinearRegression()
# [ 0.30073143 -1.86412461  0.35975412  0.3032762   0.85943518]
# -0.008185534870511369
# Difference between r2_score and CV mean score of "LinearRegression()" is :- 85.91982713140904
#
#
# Model Name :- Ridge()
# Training Score:- 0.8135698888404782
# r2_Score 84.13
# MSE 22.77830864118279
# MAE 4.166619486401007
# RMSE 4.7726626364308204
# ****************************************************************************************************
# Cross Val Score of :- Ridge()
# [ 0.19514276 -1.71519839  0.41789934  0.7318908   0.90615657]
# 0.10717821971619819
# Difference between r2_score and CV mean score of "Ridge()" is :- 73.40947500071496
#
#
# Model Name :- Lasso()
# ...

# %% [markdown]
# Model is performing well but cross validation is not working very well with r2_score scoring parameter.Hence goint to check with different scoring parameter.

# %% [markdown]
# Checking cross validation with negative mean absolute error.

# %%
# IteratingModels
for model in models:
    model.fit(xtrain,ytrain)
    r2_scr=r2_score(ytest,model.predict(xtest))
    mse=mean_squared_error(ytest,model.predict(xtest))
    mae=mean_absolute_error(ytest,model.predict(xtest))
    print('Model Name :-',model)
    print('Training Score:-',model.score(xtrain,ytrain))
    print('r2_Score',round(r2_scr*100,2))
    print('MSE',mse)
    print('MAE',mae)
    print('RMSE',np.sqrt(mean_squared_error(ytest,model.predict(xtest))))
    print('*'*100)
    print('Cross Val Score of :-',model)
    score_m=cross_val_score(model,x1,y,scoring='neg_mean_absolute_error')
    print(score_m)
    print(score_m.mean())
    print('Difference between negative mean absolute error and CV mean score of "{}" is :-'.format(model),(-1*mae)-score_m.mean())
    print('\n')
# Out:
# Model Name :- LinearRegression()
# Training Score:- 0.822751023043963
# r2_Score 85.1
# MSE 21.380591994812804
# MAE 3.684806585876621
# RMSE 4.62391522357545
# ****************************************************************************************************
# Cross Val Score of :- LinearRegression()
# [-4.6249464  -5.2274798  -8.00377728 -8.06858824 -2.6557386 ]
# -5.716106063983913
# Difference between negative mean absolute error and CV mean score of "LinearRegression()" is :- 2.031299478107292
#
#
# Model Name :- Ridge()
# Training Score:- 0.8135698888404782
# r2_Score 84.13
# MSE 22.77830864118279
# MAE 4.166619486401007
# RMSE 4.7726626364308204
# ****************************************************************************************************
# Cross Val Score of :- Ridge()
# [-5.16444845 -5.1995072  -8.90609794 -3.8324442  -2.2000648 ]
# -5.060512518829258
# Difference between negative mean absolute error and CV mean score of "Ridge()" is :- 0.8938930324282506
#
#
# ...

# %% [markdown]
# 1) cross validation is working well with negative mean absolute error.
# 2) Ridge is r2_score of 84 and difference between negative mean absolute error and cv mean negative mean absolute error is 0.8.
# 3) Ridge is also regularization model. Hence considerint it the best performing model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
# importing Grid Searchcv
from sklearn.model_selection import GridSearchCV

# %%
alpha{float, ndarray of shape (n_targets,)}, default=1.0
solver{‘auto’, ‘svd’, ‘cholesky’, ‘lsqr’, ‘sparse_cg’, ‘sag’, ‘saga’, ‘lbfgs’}
random_state

# %%
#parameters
params={'alpha':[0.00001,0.0001,0.001,0.01,0.1,1.0],
      'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga','lbfgs'],
      'random_state':range(1,50)}

# %%
rd
# Out:
# Ridge()

# %%
gscv=GridSearchCV(rd,params,cv=5)

# %%
gscv.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1.0],
#                          'random_state': range(1, 50),
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga', 'lbfgs']})

# %%
# Best Parameters
gscv.best_params_
# Out:
# {'alpha': 1.0, 'random_state': 41, 'solver': 'saga'}

# %%
# Model
ModelRD=Ridge(alpha=1.0,random_state=41,solver='saga')

# %%
ModelRD.fit(xtrain,ytrain)
# Out:
# Ridge(random_state=41, solver='saga')

# %%
r2_score(ytest,ModelRD.predict(xtest))
# Out:
# 0.8407501143761814

# %% [markdown]
# # Saving Best Model

# %%
# importing Pickle
import pickle

# %%
filename='Baseball.pkl'

# %%
# saving best model
pickle.dump(ModelRD,open(filename,'wb'))
