# %% [markdown]
# # Project Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 14,000 power plants from 3 countries(USA, AUS, INDIA) and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# # Key attributes of the database
# The database includes the following indicators:
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
# •	`country_long` (text): longer form of the country designation
# •	`name` (text): name or title of the power plant, generally in Romanized form
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
# •	`capacity_mw` (number): electrical generating capacity in megawatts
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
# •	`other_fuel1` (text): energy source used in electricity generation or export
# •	`other_fuel2` (text): energy source used in electricity generation or export
# •	`other_fuel3` (text): energy source used in electricity generation or export
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# •	`url` (text): web document corresponding to the `source` field
# •	`geolocation_source` (text): attribution for geolocation information
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# •	`year_of_capacity_data` (number): year the capacity information was reported
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours rep•	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
# •	`generation_data_source` (text): attribution for the reported generation information
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the
# # Prediction :
# Make two prediction  1) Primary Fuel    2) capacity_mw  year 2017
# orted for the year 2017

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset
df=pd.read_csv('global_Power_plant_database.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# # EDA

# %%
# Dimension of Dataset
print('Dataset has {} Rows and {} Columns.'.format(df.shape[0],len(df.columns)))
# Out:
# Dataset has 908 Rows and 25 Columns.

# %% [markdown]
# Out of these 25 columns two columns are target variable. one (capacity_mw) for regression task and other(primary_fuel) for classofication task.

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   908 non-null    object
#  1   country_long              908 non-null    object
#  2   name                      908 non-null    object
#  3   gppd_idnr                 908 non-null    object
#  4   capacity_mw               908 non-null    float64
#  5   latitude                  862 non-null    float64
#  6   longitude                 862 non-null    float64
#  7   primary_fuel              908 non-null    object
#  8   other_fuel1               199 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        528 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
# Datatypes in dataset
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %% [markdown]
# Dataset contains two types of data Float and Object.

# %%
# Top 10 rows
df.head(10)
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
# 5     IND        India              AKRIMOTA LIG  IND0000003        250.0
# 6     IND        India                    ALIYAR  IND0000004         60.0
# 7     IND        India           ALLAIN DUHANGAN  IND0000005        192.0
# 8     IND        India               ALMATTI DAM  IND0000006        290.0
# 9     IND        India               AMAR KANTAK  IND0000007        210.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# ...

# %%
# Bottom 10 rows
df.tail(10)
# Out:
#     country country_long                                               name  \
# 898     IND        India  Wind power project by Riddhi Siddhi Gluco Biol...
# 899     IND        India                    Wind power project in Rajasthan
# 900     IND        India                                    YAMUNANAGAR TPP
# 901     IND        India                                 YASHWANTRAO MOHITE
# 902     IND        India                                      YELHANKA (DG)
# 903     IND        India                                       YERMARUS TPP
# 904     IND        India                       Yelesandra Solar Power Plant
# 905     IND        India                       Yelisirur wind power project
# 906     IND        India                                        ZAWAR MINES
# 907     IND        India                            iEnergy Theni Wind Farm
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
# Null Values in the Datates
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# In other fuel3, wepp_id and Estimated generation gwh column has null values in all the rows.So we are going to drop these columns.

# %%
# Null value Percentage
df.isnull().sum()/df.shape[0]*100
# Out:
# country                       0.000000
# country_long                  0.000000
# name                          0.000000
# gppd_idnr                     0.000000
# capacity_mw                   0.000000
# latitude                      5.066079
# longitude                     5.066079
# primary_fuel                  0.000000
# other_fuel1                  78.083700
# other_fuel2                  99.889868
# other_fuel3                 100.000000
# commissioning_year           41.850220
# owner                        62.334802
# source                        0.000000
# url                           0.000000
# geolocation_source            2.092511
# wepp_id                     100.000000
# year_of_capacity_data        42.731278
# generation_gwh_2013          57.709251
# generation_gwh_2014          55.837004
# generation_gwh_2015          53.193833
# generation_gwh_2016          51.872247
# generation_gwh_2017          51.211454
# generation_data_source       50.440529
# ...

# %% [markdown]
# 5 columns have more than 70 % null values. Therefore, we are going to drop these columns.

# %%
# Dropping Columns which have above 70 % Null Values 
df.drop(columns={'other_fuel1','other_fuel2','other_fuel3','wepp_id','estimated_generation_gwh'},inplace=True)

# %%
# Checking Value count and count of unique Value in each column
for d in df.columns:
    print(d)
    print(df[d].value_counts())
    print(df[d].nunique())
    print('\n')
# Out:
# country
# country
# IND    908
# Name: count, dtype: int64
# 1
#
#
# country_long
# country_long
# India    908
# Name: count, dtype: int64
# 1
#
#
# name
# name
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADAMPARI                  1
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# iEnergy Theni Wind Farm    1
# Name: count, Length: 908, dtype: int64
# 908
#
#
# gppd_idnr
# gppd_idnr
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000166    1
# IND0000167    1
# IND0000168    1
# IND0000169    1
# WRI1026761    1
# Name: count, Length: 908, dtype: int64
# 908
#
#
# capacity_mw
# capacity_mw
# 5.0       39
# 10.0      22
# 600.0     21
# 15.0      20
# 1200.0    19
#           ..
# 645.0      1
# 41.4       1
# 17.5       1
# ...

# %% [markdown]
# 1) Country, Country_long, Year of capacity data and generational data source have same value in each rows which is not very helpul in prediction, therefore going to drop these columns.
# 2) name and gppd_idnr are unique columns. so going to drop these columns.
# 3) owner and url is not needed for prediction. hence going to drop these columns too.
# 4) generation_gwh_2013 to 17 these four columns have some rows with 0 value which we considering it as null values.

# %%
# Dropping Columns which is Not important for the prediction
df.drop(columns={'country','country_long','name','gppd_idnr','owner','url','year_of_capacity_data','generation_data_source'},inplace=True)

# %%
df.shape
# Out:
# (908, 12)

# %%
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     380
# source                   0
# geolocation_source      19
# generation_gwh_2013    524
# generation_gwh_2014    507
# generation_gwh_2015    483
# generation_gwh_2016    471
# generation_gwh_2017    465
# dtype: int64

# %%
# Description of Dataset
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   908.000000  862.000000  862.000000          528.000000
# mean    321.046378   21.196189   77.447848         1996.876894
# std     580.221767    6.248627    4.907260           17.047817
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.837500   16.771575   74.258975         1988.000000
# 50%      60.000000   21.778300   76.719250         2000.000000
# 75%     388.125000   25.516375   79.441475         2011.250000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# count           384.000000           401.000000           425.000000
# mean           2304.059202          2420.393316          2414.072373
# std            3794.767492          4013.558173          4183.203199
# min               0.000000             0.000000             0.000000
# ...

# %% [markdown]
# 1) In capacity_mw column minimum value is 0. which means some rows have 0 as value. hence it is our target variable we are going to drop these rows.
# 2) Commisioning year is year column so we are going to fill it's null values with median.
# 3) Apart from longitude, latitude and commisioning year all other columns have huge difference between 75th percentile and maximum data. which means outliers are present in these columns. So we are fill null values with median of the data because it's more robust to outliers comapred to mean of the data.

# %%
# Checking rows having 0 as capacity_mw value.
df[df['capacity_mw']==0]
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 830          0.0   12.8491    77.6752        Solar                 NaN
#
#                           source geolocation_source  generation_gwh_2013  \
# 830  Tata BP Solar India Limited     Industry About                  NaN
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 830                  NaN                  NaN                  NaN
#
#      generation_gwh_2017
# 830                  NaN

# %%
# Dropping rows which has 0 as capacity_mw value
df=df[df['capacity_mw']>0]

# %%
df[df['capacity_mw']==0]
# Out:
# Empty DataFrame
# Columns: [capacity_mw, latitude, longitude, primary_fuel, commissioning_year, source, geolocation_source, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017]
# Index: []

# %%
# Checking how many rows have 0 as value in other columns
print('generation_gwh_2013',df[df['generation_gwh_2013']==0].shape)
print('generation_gwh_2014',df[df['generation_gwh_2014']==0].shape)
print('generation_gwh_2015',df[df['generation_gwh_2015']==0].shape)
print('generation_gwh_2016',df[df['generation_gwh_2016']==0].shape)
print('generation_gwh_2017',df[df['generation_gwh_2017']==0].shape)
# Out:
# generation_gwh_2013 (21, 12)
# generation_gwh_2014 (28, 12)
# generation_gwh_2015 (28, 12)
# generation_gwh_2016 (31, 12)
# generation_gwh_2017 (33, 12)

# %%
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     379
# source                   0
# geolocation_source      19
# generation_gwh_2013    523
# generation_gwh_2014    506
# generation_gwh_2015    482
# generation_gwh_2016    470
# generation_gwh_2017    464
# dtype: int64

# %%
# Replacing 0 as null value
df.replace(0,np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     379
# source                   0
# geolocation_source      19
# generation_gwh_2013    544
# generation_gwh_2014    534
# generation_gwh_2015    510
# generation_gwh_2016    501
# generation_gwh_2017    497
# dtype: int64

# %%
# Filling Null values
for d in df.columns:
    if df[d].dtype=='object':
        df[d].fillna(df[d].mode()[0],inplace=True)
    elif df[d].dtype!='object':
        df[d].fillna(df[d].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# commissioning_year     0
# source                 0
# geolocation_source     0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# dtype: int64

# %%
df.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# commissioning_year     float64
# source                  object
# geolocation_source      object
# generation_gwh_2013    float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# dtype: object

# %%
df['commissioning_year']
# Out:
# 0      2011.0
# 1      2000.0
# 2      2000.0
# 3      2004.0
# 4      2015.0
#         ...
# 903    2016.0
# 904    2000.0
# 905    2000.0
# 906    2000.0
# 907    2000.0
# Name: commissioning_year, Length: 907, dtype: float64

# %%
# Changing DataType
df['commissioning_year']=df['commissioning_year'].astype('int')

# %%
df.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# commissioning_year       int32
# source                  object
# geolocation_source      object
# generation_gwh_2013    float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# dtype: object

# %%
df['commissioning_year']
# Out:
# 0      2011
# 1      2000
# 2      2000
# 3      2004
# 4      2015
#        ...
# 903    2016
# 904    2000
# 905    2000
# 906    2000
# 907    2000
# Name: commissioning_year, Length: 907, dtype: int32

# %% [markdown]
# # Graphical Analysis

# %% [markdown]
# Univariate Analysis

# %%
# Data Distribution in capacity_mw
sns.distplot(df['capacity_mw'])
plt.title('Data distribution in Capacity_mw')
plt.show()

# %% [markdown]
# Right skewed data distribution in capacity_mw. which means Mean is greater than the Median.

# %%
# Data distribution in latitude
sns.distplot(df['latitude'])
plt.title('Data distribution in Latitude column')
plt.show()

# %% [markdown]
# Data distribution is looking normal in Latitude column.

# %%
sns.distplot(df['longitude'])
plt.title('Data distribution in Longitude column')
plt.show()

# %% [markdown]
# Slighty right skewed data distribution in longitude Column.

# %%
sns.distplot(df['commissioning_year'])
plt.title('Data distribution in commissioning year column')
plt.show()

# %% [markdown]
# Peak of the data is on value 2000, which is higher side of the data. which means data is left skewed.

# %%
sns.distplot(df['generation_gwh_2013'])
plt.title('Data distribution in generation_gwh_2013 column')
plt.show()

# %% [markdown]
# Right skewed distribution in generation_gwh_2013.

# %%
sns.distplot(df['generation_gwh_2014'])
plt.title('Data distribution in generation_gwh_2014 column')
plt.show()

# %% [markdown]
# generation_gwh_2014 has right skewed data distribution.

# %%
sns.distplot(df['generation_gwh_2015'])
plt.title('Data distribution in generation_gwh_2015 column')
plt.show()

# %%
sns.distplot(df['generation_gwh_2016'])
plt.title('Data distribution in generation_gwh_2016 column')
plt.show()

# %%
sns.distplot(df['generation_gwh_2017'])
plt.title('Data distribution in generation_gwh_2017 column')
plt.show()

# %% [markdown]
# generation_gwh_2013, generation_gwh_2016 and generation_gwh_2017 all these three columns have right skewed data distribution.

# %% [markdown]
# Bivariate Analysis

# %%
sns.countplot(y='geolocation_source',data=df,hue='primary_fuel')
plt.title('Count of primary fuel at each Geolocation_source')
plt.show()

# %% [markdown]
# WRI geolocation source has all kind of primary fuel. Count of coal is highest followed by Hydro.

# %%
sns.scatterplot(x='capacity_mw',y='generation_gwh_2013',data=df)
plt.title('Relation between generation_gwh_2013 and capacity_mw')
plt.show()

# %% [markdown]
# Generation_gwh_2013 has positive relation with capacity_mw which means if generation_gwh_2013 is increasing capacity_mw is increasing too.

# %%
sns.scatterplot(x='capacity_mw',y='generation_gwh_2014',data=df)
plt.title('Relation between capacity_mw and generation_gwh_2014')
plt.show()

# %%
sns.scatterplot(x='capacity_mw',y='generation_gwh_2015',data=df)
plt.title('Relation Between capacity_mw and generation_gwh_2015')
plt.show()

# %%
sns.scatterplot(x='capacity_mw',y='generation_gwh_2016',data=df)
plt.title('Relation between cpacity_mw and generation_gwh_2016')
plt.show()

# %%
sns.scatterplot(x='capacity_mw',y='generation_gwh_2017',data=df)
plt.title('Relation between capacity_mw and generation_gwh_2017')
plt.show()

# %% [markdown]
# generation_gwh_2014, generation_gwh_2015, generation_gwh_2016 and generation_gwh_2017 all these four columns also have positive relation with capacity_mw

# %% [markdown]
# # Outliers

# %%
# Plotting Box plot to check ouliers
df.plot(kind='box',subplots=True,layout=(2,5),figsize=(15,10))
plt.tight_layout()

# %% [markdown]
# 1) Apart from latitude all other columns have outliers present in them.
# 2) Though capacity_mw is our target variable in this task so we are not going to remove outliers from it.

# %%
# Importing zscore
from scipy.stats import zscore

# %%
zr=np.abs(zscore(df[['latitude','longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']]))

# %%
# Threshold = 3
print(np.where(zr>3))
# Out:
# (array([ 15,  15,  15, 144, 144, 144, 144, 144, 159, 159, 180, 184, 210,
#        210, 210, 210, 210, 222, 240, 245, 309, 309, 309, 309, 309, 324,
#        334, 341, 343, 361, 365, 365, 365, 365, 365, 372, 389, 417, 428,
#        445, 455, 479, 485, 494, 494, 494, 494, 494, 495, 495, 495, 495,
#        495, 500, 520, 530, 533, 533, 539, 542, 547, 575, 584, 593, 602,
#        622, 624, 639, 649, 649, 649, 649, 649, 658, 658, 658, 658, 658,
#        696, 696, 696, 696, 707, 710, 722, 722, 722, 722, 722, 725, 725,
#        725, 725, 725, 727, 727, 727, 727, 727, 729, 787, 787, 787, 787,
#        787, 808, 809, 809, 809, 809, 809, 819, 847, 848, 848, 880, 880,
#        880, 880, 880], dtype=int64), array([5, 6, 7, 3, 4, 5, 6, 7, 3, 4, 1, 1, 3, 4, 5, 6, 7, 2, 1, 1, 3, 4,
#        5, 6, 7, 1, 1, 1, 2, 1, 3, 4, 5, 6, 7, 2, 1, 1, 1, 2, 2, 2, 2, 3,
#        4, 5, 6, 7, 3, 4, 5, 6, 7, 1, 1, 1, 3, 4, 2, 2, 1, 2, 2, 2, 2, 2,
# ...

# %%
dfnr=df[np.abs(zr<3).all(axis=1)]

# %%
# Data loss percent due to outliers
(df.shape[0]-dfnr.shape[0])/df.shape[0]*100
# Out:
# 6.174200661521499

# %% [markdown]
# 6.17 % of data lost due to outliers.

# %% [markdown]
# # Encoding

# %%
# Creating encoding function
def Encoding(data):
    from sklearn.preprocessing import LabelEncoder
    for d in data.columns:
        if data[d].dtype=='object':
            data[d]=LabelEncoder().fit_transform(data[d])
    return data

# %%
# Encoding data
Encoding(dfnr)
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6                2011
# 1           98.0   24.7663    74.6090             1                2000
# 2           39.2   21.9038    69.3732             7                2000
# 3          135.0   23.8712    91.3602             2                2004
# 4         1800.0   21.9603    82.4091             1                2015
# ..           ...       ...        ...           ...                 ...
# 903       1600.0   16.2949    77.3568             1                2016
# 904          3.0   12.8932    78.1654             6                2000
# 905         25.5   15.2758    75.5811             7                2000
# 906         80.0   24.3500    73.7477             1                2000
# 907         16.5    9.9344    77.4768             7                2000
#
#      source  geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# ...

# %%
dfnr.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel             int32
# commissioning_year       int32
# source                   int32
# geolocation_source       int32
# generation_gwh_2013    float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# dtype: object

# %% [markdown]
# # Skewness

# %%
# Cheking skewness
dfnr.skew()
# Out:
# capacity_mw            2.132483
# latitude              -0.125726
# longitude              0.888812
# primary_fuel           0.416988
# commissioning_year    -1.208697
# source                 1.738330
# geolocation_source    -2.080569
# generation_gwh_2013    3.119890
# generation_gwh_2014    2.962473
# generation_gwh_2015    2.737805
# generation_gwh_2016    2.652523
# generation_gwh_2017    2.539092
# dtype: float64

# %% [markdown]
# 1) Skewness is present in capacity_mw, longitude, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016 and generation_gwh_2017.
# 2) capacity_mw is our target variable in this task so not going to remove skewness from this column.

# %%
# Importing powertransformer
from sklearn.preprocessing import PowerTransformer

# %%
# Removing skewness
dfnr[['longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']]=PowerTransformer().fit_transform(dfnr[['longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']])

# %%
dfnr.skew()
# Out:
# capacity_mw            2.132483
# latitude              -0.125726
# longitude              0.000237
# primary_fuel           0.416988
# commissioning_year    -0.218719
# source                 1.738330
# geolocation_source    -2.080569
# generation_gwh_2013    0.225901
# generation_gwh_2014    0.223847
# generation_gwh_2015    0.166497
# generation_gwh_2016    0.130465
# generation_gwh_2017    0.135580
# dtype: float64

# %% [markdown]
# # Correlation

# %%
# heatmap with correlation matrix
plt.figure(figsize=(15,10))
sns.heatmap(dfnr.corr(),annot=True)
plt.show()

# %% [markdown]
# Capacity_mw:-
# 1) generation_gwh_2017 has highest positive correlation with capacity_mw
# 2) primary_fuel has highest negative correlation with capacity_mw

# %% [markdown]
# Primary_fuel:-
# 1) geolocation source has highest negative correlation with primary fuel. followed by longitude.
# 2) apart from these two no other column has very significant correlation with primary_fuel.

# %%
# Splitting input output variable
xr=dfnr.drop(columns={'capacity_mw'})
yr=dfnr['capacity_mw']

# %% [markdown]
# # Scaling

# %%
# Creating scaling function
def Scaling(data):
    from sklearn.preprocessing import StandardScaler
    data=pd.DataFrame(StandardScaler().fit_transform(data),columns=data.columns)
    return data

# %%
# Scaling input data
xr=Scaling(xr)

# %%
xr
# Out:
#      latitude  longitude  primary_fuel  commissioning_year    source  \
# 0    1.152612  -0.923177      1.177311            1.197045  1.411222
# 1    0.592276  -0.499896     -0.972671           -0.053316  2.821952
# 2    0.122952  -2.372617      1.607307           -0.053316 -0.528532
# 3    0.445519   2.491137     -0.542675            0.365378 -0.506489
# 4    0.132215   1.284839     -0.972671            1.735521 -0.506489
# ..        ...        ...           ...                 ...       ...
# 846 -0.796661   0.237459     -0.972671            1.877990 -0.506489
# 847 -1.354391   0.429413      1.177311           -0.053316  0.705857
# 848 -0.963749  -0.222940      1.607307           -0.053316 -0.528532
# 849  0.524021  -0.761540     -0.972671           -0.053316  0.309089
# 850 -1.839504   0.266610      1.607307           -0.053316 -0.528532
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0             -1.043598            -0.029562            -0.028107
# ...

# %% [markdown]
# # Multicolinearity

# %%
# Creating vif function
def calc_vif(data):
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    vif=pd.DataFrame()
    vif['Columns']=data.columns
    vif['VIF']=[variance_inflation_factor(data.values,i) for i in range(len(data.columns))]
    print(vif)

# %%
calc_vif(xr)
# Out:
#                 Columns       VIF
# 0              latitude  1.092264
# 1             longitude  1.321090
# 2          primary_fuel  1.710005
# 3    commissioning_year  1.151306
# 4                source  1.507305
# 5    geolocation_source  1.960588
# 6   generation_gwh_2013  3.757474
# 7   generation_gwh_2014  4.922636
# 8   generation_gwh_2015  4.125594
# 9   generation_gwh_2016  6.303191
# 10  generation_gwh_2017  4.669600

# %% [markdown]
# No Multicolinearity present in dataset

# %% [markdown]
# # Random_State

# %%
# Creating random state class for regression and classification task
class random_state:
    def __init__(self,model,x,y):
        self.model=model
        self.x=x
        self.y=y
    
    def regression(self):
        from sklearn.model_selection import train_test_split
        from sklearn.metrics import r2_score
        rs=0
        r2=0
        for i in range(1,200):
            x_train,x_test,y_train,y_test=train_test_split(self.x,self.y,test_size=0.30,random_state=i)
            self.model.fit(x_train,y_train)
            r2s=r2_score(y_test,self.model.predict(x_test))
            if r2s>r2:
                r2=r2s
                rs=i
        print('Best R2score {} at random state {}.'.format(r2,rs))

    def classification(self):
        rs=0
        acc=0
        from sklearn.model_selection import train_test_split
        from sklearn.metrics import accuracy_score
        for i in range(1,200):
            x_train,x_test,y_train,y_test=train_test_split(self.x,self.y,test_size=0.30,random_state=i)
            self.model.fit(x_train,y_train)
            accu=accuracy_score(y_test,self.model.predict(x_test))
            if accu>acc:
                acc=accu
                rs=i
        print('Best accuracy {} at random state {}.'.format(acc,rs))

# %%
# Importing ML libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score

# %%
# Finding best random state
random_state(LinearRegression(),xr,yr).regression()
# Out:
# Best R2score 0.6559678635241123 at random state 54.

# %%
# splitting training and testing data
xtrainr,xtestr,ytrainr,ytestr=train_test_split(xr,yr,test_size=0.30,random_state=54)

# %%
print(xtrainr.shape)
print(xtestr.shape)
print(ytrainr.shape)
print(ytestr.shape)
# Out:
# (595, 11)
# (256, 11)
# (595,)
# (256,)

# %% [markdown]
# # Models

# %%
# Importing Regression models
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Creating variables
lr=LinearRegression()
ls=Lasso()
rd=Ridge()
svr=SVR()
dtr=DecisionTreeRegressor()
etr=ExtraTreesRegressor()
abr=AdaBoostRegressor()
gbr=GradientBoostingRegressor()
rfr=RandomForestRegressor()
knr=KNeighborsRegressor()

# %%
# Creating Models list
modelsr=[lr,ls,rd,svr,dtr,etr,abr,gbr,rfr,knr]

# %%
# Creating for to check each model performance
for modelr in modelsr:
    modelr.fit(xtrainr,ytrainr)
    predr=modelr.predict(xtestr)
    r2sc=r2_score(ytestr,predr)
    print('*'*100)
    print(modelr)
    print(r2sc*100)
    print('MAE',mean_absolute_error(ytestr,predr))
    print('MSE',mean_squared_error(ytestr,predr))
    print('Cross Val Score')
    cvscr=cross_val_score(modelr,xr,yr)
    print(cvscr)
    print(cvscr.mean())
    print('Difference',round(r2sc*100-cvscr.mean()*100,2))
    print('*'*100)
    print('\n')
# Out:
# ****************************************************************************************************
# LinearRegression()
# 65.59678635241123
# MAE 189.172545403809
# MSE 71379.27437549566
# Cross Val Score
# [0.53298502 0.53361641 0.50772654 0.60042485 0.59657817]
# 0.5542661981309307
# Difference 10.17
# ****************************************************************************************************
#
#
# ****************************************************************************************************
# Lasso()
# 65.41709977693395
# MAE 189.52881581808475
# MSE 71752.08540134833
# Cross Val Score
# [0.53287524 0.53993455 0.50741513 0.60236894 0.60009325]
# 0.5565374214721904
# Difference 9.76
# ****************************************************************************************************
#
#
# ****************************************************************************************************
# Ridge()
# 65.5557888084231
# MAE 189.21822920232472
# ...

# %% [markdown]
# ExtraTreesRegressor is performing well with 83.40 % R2 score and 78.19 % CVmean score. Difference between these two scores is only 5.2 which can be consider as best performance. Hence considering it as best performing model.

# %% [markdown]
# # Hyperparameter Tunning

# %%
paramsR={'n_estimators':[int(x) for x in np.arange(start=100,stop=300,step=50)],
       'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
       'max_features':['sqrt','log2',None],
       'max_depth':[2,8,16,32,50],
       'min_samples_split':[2,4,6],
       'min_samples_leaf':[1,2],
       'bootstrap':[True, False],
       'warm_start':[True, False]}

# %%
# Importing Gridsearch CV
from sklearn.model_selection import GridSearchCV

# %%
etr
# Out:
# ExtraTreesRegressor()

# %%
gscvR=GridSearchCV(etr,paramsR)

# %%
# Search best parameters
gscvR.fit(xtrainr,ytrainr)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_depth': [2, 8, 16, 32, 50],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [100, 150, 200, 250],
#                          'warm_start': [True, False]})

# %%
# Best parameters
gscvR.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'squared_error',
#  'max_depth': 16,
#  'max_features': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 6,
#  'n_estimators': 100,
#  'warm_start': False}

# %%
ModelETR=ExtraTreesRegressor(n_estimators=100,
                             criterion='squared_error',
                             max_depth=16,
                             min_samples_split=6,
                             min_samples_leaf=2,
                             max_features=None,
                             bootstrap=False,
                             warm_start=False)

# %%
ModelETR.fit(xtrainr,ytrainr)
# Out:
# ExtraTreesRegressor(max_depth=16, max_features=None, min_samples_leaf=2,
#                     min_samples_split=6)

# %%
# Checking r2_score of model with best parameters
r2_score(ytestr,ModelETR.predict(xtestr))
# Out:
# 0.8306165530298492

# %% [markdown]
# # Saving Best model

# %%
# Importing pickle
import pickle

# %%
# Filename
filename='capacity_mw.pkl'

# %%
# Savingbest model
pickle.dump(ModelETR,open(filename,'wb'))

# %% [markdown]
# # Classification
# primary_fuel prediction

# %%
# Dataset
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar                2011
# 1           98.0   24.7663    74.6090         Coal                2000
# 2           39.2   21.9038    69.3732         Wind                2000
# 3          135.0   23.8712    91.3602          Gas                2004
# 4         1800.0   21.9603    82.4091         Coal                2015
# ..           ...       ...        ...          ...                 ...
# 903       1600.0   16.2949    77.3568         Coal                2016
# 904          3.0   12.8932    78.1654        Solar                2000
# 905         25.5   15.2758    75.5811         Wind                2000
# 906         80.0   24.3500    73.7477         Coal                2000
# 907         16.5    9.9344    77.4768         Wind                2000
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %% [markdown]
# Outliers

# %%
# boxplot for outliers
df.plot(kind='box',subplots=True,layout=(2,5),figsize=(15,10))
plt.tight_layout()

# %%
zc=np.abs(zscore(df[['capacity_mw','latitude','longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']]))

# %%
# Removing outliers
dfnc=df[np.abs(zc<3).all(axis=1)]

# %%
# data loss percentage due to outliers
(df.shape[0]-dfnc.shape[0])/df.shape[0]*100
# Out:
# 6.615214994487322

# %% [markdown]
# 6.61 % data removed due to outliers.

# %% [markdown]
# Encoding

# %%
# Encoding data
Encoding(dfnc)
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6                2011
# 1           98.0   24.7663    74.6090             1                2000
# 2           39.2   21.9038    69.3732             7                2000
# 3          135.0   23.8712    91.3602             2                2004
# 4         1800.0   21.9603    82.4091             1                2015
# ..           ...       ...        ...           ...                 ...
# 903       1600.0   16.2949    77.3568             1                2016
# 904          3.0   12.8932    78.1654             6                2000
# 905         25.5   15.2758    75.5811             7                2000
# 906         80.0   24.3500    73.7477             1                2000
# 907         16.5    9.9344    77.4768             7                2000
#
#      source  geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# ...

# %% [markdown]
# Skewness

# %%
# Checking skewness
dfnc.skew()
# Out:
# capacity_mw            1.987332
# latitude              -0.127136
# longitude              0.895172
# primary_fuel           0.409363
# commissioning_year    -1.213477
# source                 1.730846
# geolocation_source    -2.072681
# generation_gwh_2013    3.117191
# generation_gwh_2014    2.964635
# generation_gwh_2015    2.754669
# generation_gwh_2016    2.695261
# generation_gwh_2017    2.578254
# dtype: float64

# %% [markdown]
# Skewness is present in capacity_mw, longitude, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016 and generation_gwh_2017.

# %%
# Importing powertransformer
from sklearn.preprocessing import PowerTransformer

# %%
# Removing skewness
dfnc[['capacity_mw','longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']]=PowerTransformer().fit_transform(dfnc[['capacity_mw','longitude','commissioning_year','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']])

# %%
dfnc.skew()
# Out:
# capacity_mw            0.014636
# latitude              -0.127136
# longitude              0.000301
# primary_fuel           0.409363
# commissioning_year    -0.220850
# source                 1.730846
# geolocation_source    -2.072681
# generation_gwh_2013    0.227651
# generation_gwh_2014    0.224127
# generation_gwh_2015    0.168079
# generation_gwh_2016    0.134662
# generation_gwh_2017    0.139492
# dtype: float64

# %% [markdown]
# Scaling

# %%
# Splitting input and output variable
xc=dfnc.drop(columns={'primary_fuel'})
yc=dfnc['primary_fuel']

# %%
# Scaling input data
xc=Scaling(xc)

# %%
xc
# Out:
#      capacity_mw  latitude  longitude  commissioning_year    source  \
# 0      -1.686224  1.149616  -0.919533            1.208705  1.406367
# 1       0.223652  0.590398  -0.495980           -0.046210  2.814631
# 2      -0.276158  0.122011  -2.371562           -0.046210 -0.529995
# 3       0.397157  0.443934   2.488167            0.374008 -0.507991
# 4       1.760098  0.131256   1.286868            1.749143 -0.507991
# ..           ...       ...        ...                 ...       ...
# 842     1.699839 -0.795765   0.241241            1.892131 -0.507991
# 843    -1.606909 -1.352381   0.433021           -0.046210  0.702235
# 844    -0.510988 -0.962519  -0.218979           -0.046210 -0.529995
# 845     0.113312  0.522280  -0.757764           -0.046210  0.306161
# 846    -0.747191 -1.836525   0.270370           -0.046210 -0.529995
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0             -1.039637            -0.031197            -0.024519
# ...

# %% [markdown]
# Multicolinearity

# %%
# Checking vif
calc_vif(xc)
# Out:
#                 Columns       VIF
# 0           capacity_mw  1.839202
# 1              latitude  1.094168
# 2             longitude  1.200797
# 3    commissioning_year  1.178477
# 4                source  1.405176
# 5    geolocation_source  1.661370
# 6   generation_gwh_2013  3.946933
# 7   generation_gwh_2014  4.960173
# 8   generation_gwh_2015  4.158115
# 9   generation_gwh_2016  6.712708
# 10  generation_gwh_2017  4.947659

# %% [markdown]
# No Multicolinearity is present in dataset.

# %% [markdown]
# # Class imbalance

# %%
# Target variable value count
yc.value_counts()
# Out:
# primary_fuel
# 1    236
# 3    218
# 6    125
# 7    123
# 2     65
# 0     50
# 5     21
# 4      9
# Name: count, dtype: int64

# %% [markdown]
# Value count is showing that we have class imbalance problem.which we will rectify with Smote resample.

# %%
# Importing Smote
from imblearn.over_sampling import SMOTE

# %%
# Balancing class variable
xc1,yc1=SMOTE().fit_resample(xc,yc)

# %%
yc1.value_counts()
# Out:
# primary_fuel
# 6    236
# 1    236
# 7    236
# 2    236
# 3    236
# 0    236
# 5    236
# 4    236
# Name: count, dtype: int64

# %%
# Importing classification libraries
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Random State

# %%
# Finding best random state
random_state(ExtraTreesClassifier(),xc1,yc1).classification()
# Out:
# Best accuracy 0.9559082892416225 at random state 64.

# %%
# splitting training and testing data
xctrain,xctest,yctrain,yctest=train_test_split(xc1,yc1,test_size=0.30,random_state=64)

# %%
print(xctrain.shape)
print(xctest.shape)
print(yctrain.shape)
print(yctest.shape)
# Out:
# (1321, 11)
# (567, 11)
# (1321,)
# (567,)

# %% [markdown]
# Models

# %%
# Importing Classification models
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
# Importing Classification metrics
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Creating models variable
dtc=DecisionTreeClassifier()
svc=SVC()
knc=KNeighborsClassifier()
rfc=RandomForestClassifier()
abc=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
bgc=BaggingClassifier()
etc=ExtraTreesClassifier()

# %%
# Creating models list
modelsC=[dtc,svc,knc,rfc,abc,gbc,bgc,etc]

# %%
# Creating for loop to check each model performance
for modelC in modelsC:
    modelC.fit(xctrain,yctrain)
    predC=modelC.predict(xctest)
    accuracy=accuracy_score(yctest,predC)
    print(modelC)
    print(round(accuracy*100,2))
    print(confusion_matrix(yctest,predC))
    print(classification_report(yctest,predC))
    print('Cross Val Score')
    cvscC=cross_val_score(modelC,xc1,yc1)
    print(cvscC)
    print(cvscC.mean())
    print('Difference between accuracy score and cv mean score is ',round(accuracy*100-cvscC.mean()*100,2))
    print('*'*100)
    print('\n')
# Out:
# DecisionTreeClassifier()
# 88.54
# [[61  0  0  0  0  0  0  0]
#  [ 8 53  4  4  1  4  0  0]
#  [ 2 10 51  3  0  4  0  1]
#  [ 0  6  2 60  0  1  0  0]
#  [ 0  3  1  1 66  2  0  0]
#  [ 2  1  4  1  0 59  0  0]
#  [ 0  0  0  0  0  0 71  0]
#  [ 0  0  0  0  0  0  0 81]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        61
#            1       0.73      0.72      0.72        74
#            2       0.82      0.72      0.77        71
#            3       0.87      0.87      0.87        69
#            4       0.99      0.90      0.94        73
#            5       0.84      0.88      0.86        67
#            6       1.00      1.00      1.00        71
#            7       0.99      1.00      0.99        81
#
#     accuracy                           0.89       567
#    macro avg       0.88      0.89      0.88       567
# weighted avg       0.89      0.89      0.88       567
#
# Cross Val Score
# ...

# %% [markdown]
# ExtraTreesClassifier is preforming well with 94.36 % accuracy score and 93 Cvmean score. Differnece between these two scores is 0.5. Hence considering it as best performing model.

# %%
# best performing model
etc
# Out:
# ExtraTreesClassifier()

# %% [markdown]
# Hyperparameter Tunning

# %%
paramsC={'n_estimators':[100,150,200],
        'criterion':['gini','entropy','log_loss'],
        'max_features':['sqrt','log2',None],
        'class_weight':['balanced','balanced_subsample']}

# %%
# Gridsearch CV
gscvC=GridSearchCV(etc,paramsC)

# %%
# Searching best parameters
gscvC.fit(xctrain,yctrain)
# Out:
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 150, 200]})

# %%
# Best parameters
gscvC.best_params_
# Out:
# {'class_weight': 'balanced_subsample',
#  'criterion': 'log_loss',
#  'max_features': 'sqrt',
#  'n_estimators': 150}

# %%
# Creating Model with best parameters
ModelETC=ExtraTreesClassifier(n_estimators=150,
                             criterion='log_loss',
                             max_features='sqrt',
                             class_weight='balanced_subsample')

# %%
# Checking performance
ModelETC.fit(xctrain,yctrain)
print(accuracy_score(yctest,ModelETC.predict(xctest)))
# Out:
# 0.9523809523809523

# %% [markdown]
# Saving best model

# %%
# Creating filename to save best model
filename='primary_fuel.pkl'

# %%
# Saving best model
pickle.dump(ModelETC,open(filename,'wb'))
